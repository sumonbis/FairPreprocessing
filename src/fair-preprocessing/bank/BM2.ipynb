# %%
import sys
sys.path.append('../../../')
from utils.packages import *
from utils.ml_fairness import *
from utils.standard_data import *
dir = 'res/bank/'
Path(dir).mkdir(parents=True, exist_ok=True)

d_fields = ['Name', 'Stage', 'CVR', 'CVD', 'V_SPD', 'V_EOD', 'V_AOD', 'V_ERD', 'Acc', 'F1','SPD', 'EOD', 'AOD', 'ERD']
diff_file = dir + 'diff' + '.csv'
if(not os.path.isfile(diff_file)):
    with open(diff_file, 'a') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(d_fields)
    
f_count = len([name for name in os.listdir(dir) if os.path.isfile(os.path.join(dir, name)) and not name.startswith('.')])
fields = ['Acc', 'F1', 'DI','SPD', 'EOD', 'AOD', 'ERD', 'CNT', 'TI']
filename = dir + str(f_count) + '.csv'
with open(filename, 'a') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)

# %%
def custom_get_fair_metrics_and_plot(fname, data, model, model_aif=False):
    pred = model.predict(data).labels if model_aif else model.predict(data.features)
    pred = (pred >= 0.5) * 1
    fair = fair_metrics(fname, data, pred)
    return (pred, fair)

# %%
file_path = '../../data/bank/bank-additional-full.csv'

column_names = []
na_values=['unknown']

df = pd.read_csv(file_path, sep=';', na_values=na_values)

#### Drop na values
dropped = df.dropna()
count = df.shape[0] - dropped.shape[0]
print("Missing Data: {} rows removed.".format(count))
df = dropped

df['age'] = df['age'].apply(lambda x: np.float(x >= 25))

## Feature selection
# features_to_keep = []
# df = df[features_to_keep]
y2_df = df.copy()
# Create a one-hot encoding of the categorical variables.
cat_feat = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
df = pd.get_dummies(df, columns=cat_feat, prefix_sep='=')

for feature in cat_feat:
    le = LabelEncoder()
    y2_df[feature] = le.fit_transform(y2_df[feature])
# Out:
# Missing Data: 10700 rows removed.

# %%
for i in range(5):
    pro_att_name = ['age'] # ['race', 'sex']
    priv_class = [1] # ['White', 'Male']
    reamining_cat_feat = []
    seed = randrange(100)

    y2_data_orig, y2_X, y2_y = load_bank_data(y2_df, pro_att_name, priv_class, reamining_cat_feat)
    y2_data_orig_train, y2_data_orig_test = y2_data_orig.split([0.7], shuffle=True, seed=seed)

    y2_X_train = y2_data_orig_train.features
    y2_y_train = y2_data_orig_train.labels.ravel()
    y2_X_test = y2_data_orig_test.features
    y2_y_test = y2_data_orig_test.labels.ravel()

    y1_data_orig, y1_X, y1_y = load_bank_data(df, pro_att_name, priv_class, reamining_cat_feat)
    y1_data_orig_train, y1_data_orig_test = y1_data_orig.split([0.7], shuffle=True, seed=seed)

    y1_X_train = y1_data_orig_train.features
    y1_y_train = y1_data_orig_train.labels.ravel()
    y1_X_test = y1_data_orig_test.features
    y1_y_test = y1_data_orig_test.labels.ravel()

    import lightgbm as lgb
    from xgboost.sklearn import XGBClassifier

    y2_lgb_train = lgb.Dataset(data=y2_X_train, label=y2_y_train,  free_raw_data=False)
    y2_lgb_eval = lgb.Dataset(data=y2_X_test, label=y2_y_test, reference=y2_lgb_train,  free_raw_data=False)
    y2_evals_result={}
    params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'auc',
        'num_leaves': 31,
        'learning_rate': 0.05,
        'verbose': -1
    }

    y2_md = XGBClassifier()
    y2_mdl = lgb.train(params,
                    y2_lgb_train,
                    valid_sets = y2_lgb_eval,
                    num_boost_round= 150,
                    early_stopping_rounds= 25,
                    evals_result=y2_evals_result)


    y1_lgb_train = lgb.Dataset(data=y1_X_train, label=y1_y_train,  free_raw_data=False)
    y1_lgb_eval = lgb.Dataset(data=y1_X_test, label=y1_y_test, reference=y1_lgb_train,  free_raw_data=False)
    y1_evals_result={}

    y1_md = XGBClassifier()
    y1_mdl = lgb.train(params,
                    y1_lgb_train,
                    valid_sets = y1_lgb_eval,
                    num_boost_round= 150,
                    early_stopping_rounds= 25,
                    evals_result=y1_evals_result)



    # plot_model_performance(y2_mdl, y2_X_test, y2_y_test)
    y1_pred, y1_fair = custom_get_fair_metrics_and_plot(filename, y1_data_orig_test, y1_mdl)
    y2_pred, y2_fair = custom_get_fair_metrics_and_plot(filename, y2_data_orig_test, y2_mdl)



    y1_fair = y1_fair.drop(['DI', 'CNT', 'TI'], axis=1)
    y2_fair = y2_fair.drop(['DI', 'CNT', 'TI'], axis=1)
    CVR, CVD, AVR_EOD, AVD_EOD, AVR_SPD, AVD_SPD, AVD_AOD, AV_ERD = compute_new_metrics(y2_data_orig_test, y1_pred, y2_pred)
    row_y1 = y1_fair.iloc[[0]].values[0].tolist()
    row_y2 = y2_fair.iloc[[0]].values[0].tolist()
    diff = []

    diff.append(CVR)
    diff.append(CVD)
    diff.append(AVD_SPD)
    diff.append(AVD_EOD)
    diff.append(AVD_AOD)
    diff.append(AV_ERD)

    for i in range(len(row_y2)):
        if(i < 2):
            change = row_y2[i] - row_y1[i]
        else:
            sign = ''
            if(row_y2[i] >= 0 and row_y1[i] >= 0):
                sign = '(+)'
                d = abs(row_y2[i]) - abs(row_y1[i])
            if(row_y2[i] < 0 and row_y1[i] < 0):
                sign = '(-)'
                d = abs(row_y2[i]) - abs(row_y1[i])
            if(row_y2[i] < 0 and row_y1[i] >= 0):
                sign = '(+-)'
                d = row_y2[i] - row_y1[i]
            if(row_y2[i] >=0 and row_y1[i] < 0):
                sign = '(-+)'
                d = row_y2[i] - row_y1[i]
            d = round(d, 3)
            change = sign + ' ' + str(d)

        diff.append(change)

    cols = ['CVR', 'CVD ', 'AV_SPD', 'AV_EOD', 'AV_AOD', 'AV_ERD', 'Acc', 'F1','SPD', 'EOD', 'AOD', 'ERD']
    # metrics = pd.DataFrame(data=obj_fairness, index=['y1'], columns=cols)
    diff_df = pd.DataFrame(data=[diff], columns  = cols, index = ['Diff']).round(3)
    stage = 'LabelEncoder'
    model_name = 'bank2'
    diff = diff_df.iloc[0].values.tolist()
    diff.insert(0, stage)
    diff.insert(0, model_name)
    with open(diff_file, 'a') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(diff)    
        diff_df
# Out:
# [1]	valid_0's auc: 0.919658
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.923733
# [3]	valid_0's auc: 0.923999
# [4]	valid_0's auc: 0.926285
# [5]	valid_0's auc: 0.926634
# [6]	valid_0's auc: 0.926927
# [7]	valid_0's auc: 0.927171
# [8]	valid_0's auc: 0.927329
# [9]	valid_0's auc: 0.929488
# [10]	valid_0's auc: 0.934567
# [11]	valid_0's auc: 0.936874
# [12]	valid_0's auc: 0.937699
# [13]	valid_0's auc: 0.9379
# [14]	valid_0's auc: 0.938166
# [15]	valid_0's auc: 0.938788
# [16]	valid_0's auc: 0.939036
# [17]	valid_0's auc: 0.939133
# [18]	valid_0's auc: 0.939268
# [19]	valid_0's auc: 0.939478
# [20]	valid_0's auc: 0.93982
# [21]	valid_0's auc: 0.939855
# [22]	valid_0's auc: 0.939926
# [23]	valid_0's auc: 0.939912
# [24]	valid_0's auc: 0.940104
# [25]	valid_0's auc: 0.940355
# [26]	valid_0's auc: 0.940439
# [27]	valid_0's auc: 0.941488
# [28]	valid_0's auc: 0.941545
# [29]	valid_0's auc: 0.941747
# [30]	valid_0's auc: 0.941915
# [31]	valid_0's auc: 0.942185
# [32]	valid_0's auc: 0.942263
# [33]	valid_0's auc: 0.942285
# [34]	valid_0's auc: 0.942356
# [35]	valid_0's auc: 0.942957
# [36]	valid_0's auc: 0.942959
# [37]	valid_0's auc: 0.943009
# [38]	valid_0's auc: 0.943017
# [39]	valid_0's auc: 0.943378
# [40]	valid_0's auc: 0.943422
# [41]	valid_0's auc: 0.943559
# [42]	valid_0's auc: 0.943666
# [43]	valid_0's auc: 0.943695
# [44]	valid_0's auc: 0.943759
# [45]	valid_0's auc: 0.943737
# [46]	valid_0's auc: 0.94375
# [47]	valid_0's auc: 0.943746
# [48]	valid_0's auc: 0.94373
# [49]	valid_0's auc: 0.943754
# [50]	valid_0's auc: 0.943794
# [51]	valid_0's auc: 0.943571
# [52]	valid_0's auc: 0.943603
# [53]	valid_0's auc: 0.943634
# [54]	valid_0's auc: 0.943664
# [55]	valid_0's auc: 0.94367
# [56]	valid_0's auc: 0.943676
# [57]	valid_0's auc: 0.943667
# [58]	valid_0's auc: 0.943689
# [59]	valid_0's auc: 0.943709
# [60]	valid_0's auc: 0.943701
# [61]	valid_0's auc: 0.943724
# [62]	valid_0's auc: 0.943727
# [63]	valid_0's auc: 0.943685
# [64]	valid_0's auc: 0.943665
# [65]	valid_0's auc: 0.943711
# [66]	valid_0's auc: 0.943664
# [67]	valid_0's auc: 0.943647
# [68]	valid_0's auc: 0.943646
# [69]	valid_0's auc: 0.943624
# [70]	valid_0's auc: 0.943728
# [71]	valid_0's auc: 0.943684
# [72]	valid_0's auc: 0.94401
# [73]	valid_0's auc: 0.944005
# [74]	valid_0's auc: 0.944052
# [75]	valid_0's auc: 0.94407
# [76]	valid_0's auc: 0.944133
# [77]	valid_0's auc: 0.944156
# [78]	valid_0's auc: 0.944185
# [79]	valid_0's auc: 0.944176
# [80]	valid_0's auc: 0.944194
# [81]	valid_0's auc: 0.944263
# [82]	valid_0's auc: 0.944263
# [83]	valid_0's auc: 0.944318
# [84]	valid_0's auc: 0.944312
# [85]	valid_0's auc: 0.944304
# [86]	valid_0's auc: 0.94431
# [87]	valid_0's auc: 0.944282
# [88]	valid_0's auc: 0.944261
# [89]	valid_0's auc: 0.944321
# [90]	valid_0's auc: 0.94429
# [91]	valid_0's auc: 0.944311
# [92]	valid_0's auc: 0.944295
# [93]	valid_0's auc: 0.944282
# [94]	valid_0's auc: 0.944284
# [95]	valid_0's auc: 0.944258
# [96]	valid_0's auc: 0.944282
# [97]	valid_0's auc: 0.944288
# [98]	valid_0's auc: 0.944265
# [99]	valid_0's auc: 0.94423
# [100]	valid_0's auc: 0.944224
# [101]	valid_0's auc: 0.944301
# [102]	valid_0's auc: 0.944286
# [103]	valid_0's auc: 0.944328
# [104]	valid_0's auc: 0.944354
# [105]	valid_0's auc: 0.944321
# [106]	valid_0's auc: 0.944316
# [107]	valid_0's auc: 0.944307
# [108]	valid_0's auc: 0.94432
# [109]	valid_0's auc: 0.944289
# [110]	valid_0's auc: 0.944269
# [111]	valid_0's auc: 0.944245
# [112]	valid_0's auc: 0.944293
# [113]	valid_0's auc: 0.944259
# [114]	valid_0's auc: 0.944239
# [115]	valid_0's auc: 0.944252
# [116]	valid_0's auc: 0.944219
# [117]	valid_0's auc: 0.944208
# [118]	valid_0's auc: 0.944204
# [119]	valid_0's auc: 0.944156
# [120]	valid_0's auc: 0.944138
# [121]	valid_0's auc: 0.94417
# [122]	valid_0's auc: 0.944134
# [123]	valid_0's auc: 0.944106
# [124]	valid_0's auc: 0.944123
# [125]	valid_0's auc: 0.944119
# [126]	valid_0's auc: 0.944168
# [127]	valid_0's auc: 0.944176
# [128]	valid_0's auc: 0.944129
# [129]	valid_0's auc: 0.944084
# Early stopping, best iteration is:
# [104]	valid_0's auc: 0.944354
# [1]	valid_0's auc: 0.919057
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.922922
# [3]	valid_0's auc: 0.923855
# [4]	valid_0's auc: 0.926216
# [5]	valid_0's auc: 0.926474
# [6]	valid_0's auc: 0.926798
# [7]	valid_0's auc: 0.927071
# [8]	valid_0's auc: 0.931794
# [9]	valid_0's auc: 0.93371
# [10]	valid_0's auc: 0.933954
# [11]	valid_0's auc: 0.936646
# [12]	valid_0's auc: 0.937526
# [13]	valid_0's auc: 0.937895
# [14]	valid_0's auc: 0.937668
# [15]	valid_0's auc: 0.939027
# [16]	valid_0's auc: 0.939247
# [17]	valid_0's auc: 0.939363
# [18]	valid_0's auc: 0.939217
# [19]	valid_0's auc: 0.939259
# [20]	valid_0's auc: 0.939349
# [21]	valid_0's auc: 0.939904
# [22]	valid_0's auc: 0.939852
# [23]	valid_0's auc: 0.94011
# [24]	valid_0's auc: 0.940293
# [25]	valid_0's auc: 0.940487
# [26]	valid_0's auc: 0.940697
# [27]	valid_0's auc: 0.940968
# [28]	valid_0's auc: 0.941958
# [29]	valid_0's auc: 0.942133
# [30]	valid_0's auc: 0.942326
# [31]	valid_0's auc: 0.942399
# [32]	valid_0's auc: 0.942403
# [33]	valid_0's auc: 0.942553
# [34]	valid_0's auc: 0.942668
# [35]	valid_0's auc: 0.942829
# [36]	valid_0's auc: 0.942999
# [37]	valid_0's auc: 0.943033
# [38]	valid_0's auc: 0.94303
# [39]	valid_0's auc: 0.943655
# [40]	valid_0's auc: 0.943846
# [41]	valid_0's auc: 0.943911
# [42]	valid_0's auc: 0.943988
# [43]	valid_0's auc: 0.943956
# [44]	valid_0's auc: 0.943961
# [45]	valid_0's auc: 0.943988
# [46]	valid_0's auc: 0.943922
# [47]	valid_0's auc: 0.943891
# [48]	valid_0's auc: 0.943886
# [49]	valid_0's auc: 0.943986
# [50]	valid_0's auc: 0.944038
# [51]	valid_0's auc: 0.943991
# [52]	valid_0's auc: 0.944044
# [53]	valid_0's auc: 0.944148
# [54]	valid_0's auc: 0.944162
# [55]	valid_0's auc: 0.944135
# [56]	valid_0's auc: 0.944141
# [57]	valid_0's auc: 0.944189
# [58]	valid_0's auc: 0.944254
# [59]	valid_0's auc: 0.944262
# [60]	valid_0's auc: 0.944273
# [61]	valid_0's auc: 0.944344
# [62]	valid_0's auc: 0.944294
# [63]	valid_0's auc: 0.94432
# [64]	valid_0's auc: 0.94435
# [65]	valid_0's auc: 0.944351
# [66]	valid_0's auc: 0.944346
# [67]	valid_0's auc: 0.944353
# [68]	valid_0's auc: 0.944357
# [69]	valid_0's auc: 0.944407
# [70]	valid_0's auc: 0.944357
# [71]	valid_0's auc: 0.944425
# [72]	valid_0's auc: 0.944396
# [73]	valid_0's auc: 0.944403
# [74]	valid_0's auc: 0.944411
# [75]	valid_0's auc: 0.944478
# [76]	valid_0's auc: 0.94448
# [77]	valid_0's auc: 0.944433
# [78]	valid_0's auc: 0.944447
# [79]	valid_0's auc: 0.944448
# [80]	valid_0's auc: 0.9445
# [81]	valid_0's auc: 0.944465
# [82]	valid_0's auc: 0.944472
# [83]	valid_0's auc: 0.944474
# [84]	valid_0's auc: 0.94449
# [85]	valid_0's auc: 0.944503
# [86]	valid_0's auc: 0.944475
# [87]	valid_0's auc: 0.94449
# [88]	valid_0's auc: 0.944476
# [89]	valid_0's auc: 0.944439
# [90]	valid_0's auc: 0.944431
# [91]	valid_0's auc: 0.944455
# [92]	valid_0's auc: 0.944433
# [93]	valid_0's auc: 0.944459
# [94]	valid_0's auc: 0.944422
# [95]	valid_0's auc: 0.944442
# [96]	valid_0's auc: 0.944455
# [97]	valid_0's auc: 0.944464
# [98]	valid_0's auc: 0.944431
# [99]	valid_0's auc: 0.944387
# [100]	valid_0's auc: 0.944424
# [101]	valid_0's auc: 0.944393
# [102]	valid_0's auc: 0.944348
# [103]	valid_0's auc: 0.944326
# [104]	valid_0's auc: 0.944341
# [105]	valid_0's auc: 0.944332
# [106]	valid_0's auc: 0.944304
# [107]	valid_0's auc: 0.944262
# [108]	valid_0's auc: 0.94424
# [109]	valid_0's auc: 0.94428
# [110]	valid_0's auc: 0.944277
# Early stopping, best iteration is:
# [85]	valid_0's auc: 0.944503
# Unprinv: age 0.0
# [1]	valid_0's auc: 0.926404
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.927065
# [3]	valid_0's auc: 0.927631
# [4]	valid_0's auc: 0.928659
# [5]	valid_0's auc: 0.92913
# [6]	valid_0's auc: 0.929261
# [7]	valid_0's auc: 0.929557
# [8]	valid_0's auc: 0.929702
# [9]	valid_0's auc: 0.929909
# [10]	valid_0's auc: 0.929857
# [11]	valid_0's auc: 0.930005
# [12]	valid_0's auc: 0.935686
# [13]	valid_0's auc: 0.936981
# [14]	valid_0's auc: 0.937271
# [15]	valid_0's auc: 0.93747
# [16]	valid_0's auc: 0.937155
# [17]	valid_0's auc: 0.937768
# [18]	valid_0's auc: 0.93802
# [19]	valid_0's auc: 0.938233
# [20]	valid_0's auc: 0.938436
# [21]	valid_0's auc: 0.939179
# [22]	valid_0's auc: 0.940226
# [23]	valid_0's auc: 0.940572
# [24]	valid_0's auc: 0.940655
# [25]	valid_0's auc: 0.940784
# [26]	valid_0's auc: 0.941071
# [27]	valid_0's auc: 0.942364
# [28]	valid_0's auc: 0.943149
# [29]	valid_0's auc: 0.943409
# [30]	valid_0's auc: 0.943545
# [31]	valid_0's auc: 0.943782
# [32]	valid_0's auc: 0.943909
# [33]	valid_0's auc: 0.943965
# [34]	valid_0's auc: 0.944143
# [35]	valid_0's auc: 0.944229
# [36]	valid_0's auc: 0.944324
# [37]	valid_0's auc: 0.944314
# [38]	valid_0's auc: 0.944292
# [39]	valid_0's auc: 0.944341
# [40]	valid_0's auc: 0.94441
# [41]	valid_0's auc: 0.944502
# [42]	valid_0's auc: 0.944531
# [43]	valid_0's auc: 0.944539
# [44]	valid_0's auc: 0.944636
# [45]	valid_0's auc: 0.944634
# [46]	valid_0's auc: 0.944694
# [47]	valid_0's auc: 0.944669
# [48]	valid_0's auc: 0.944708
# [49]	valid_0's auc: 0.944749
# [50]	valid_0's auc: 0.94495
# [51]	valid_0's auc: 0.945025
# [52]	valid_0's auc: 0.945092
# [53]	valid_0's auc: 0.94517
# [54]	valid_0's auc: 0.9452
# [55]	valid_0's auc: 0.945237
# [56]	valid_0's auc: 0.945313
# [57]	valid_0's auc: 0.945413
# [58]	valid_0's auc: 0.945444
# [59]	valid_0's auc: 0.945436
# [60]	valid_0's auc: 0.945467
# [61]	valid_0's auc: 0.945504
# [62]	valid_0's auc: 0.945498
# [63]	valid_0's auc: 0.945541
# [64]	valid_0's auc: 0.94553
# [65]	valid_0's auc: 0.945561
# [66]	valid_0's auc: 0.94558
# [67]	valid_0's auc: 0.945595
# [68]	valid_0's auc: 0.945608
# [69]	valid_0's auc: 0.945602
# [70]	valid_0's auc: 0.9456
# [71]	valid_0's auc: 0.945601
# [72]	valid_0's auc: 0.945623
# [73]	valid_0's auc: 0.945653
# [74]	valid_0's auc: 0.94563
# [75]	valid_0's auc: 0.945607
# [76]	valid_0's auc: 0.945618
# [77]	valid_0's auc: 0.945698
# [78]	valid_0's auc: 0.94569
# [79]	valid_0's auc: 0.94564
# [80]	valid_0's auc: 0.945646
# [81]	valid_0's auc: 0.945616
# [82]	valid_0's auc: 0.945589
# [83]	valid_0's auc: 0.945585
# [84]	valid_0's auc: 0.945541
# [85]	valid_0's auc: 0.945536
# [86]	valid_0's auc: 0.94553
# [87]	valid_0's auc: 0.945493
# [88]	valid_0's auc: 0.945498
# [89]	valid_0's auc: 0.945558
# [90]	valid_0's auc: 0.945546
# [91]	valid_0's auc: 0.945534
# [92]	valid_0's auc: 0.945545
# [93]	valid_0's auc: 0.945577
# [94]	valid_0's auc: 0.945519
# [95]	valid_0's auc: 0.945493
# [96]	valid_0's auc: 0.945486
# [97]	valid_0's auc: 0.945486
# [98]	valid_0's auc: 0.945478
# [99]	valid_0's auc: 0.945465
# [100]	valid_0's auc: 0.945427
# [101]	valid_0's auc: 0.945435
# [102]	valid_0's auc: 0.945476
# Early stopping, best iteration is:
# [77]	valid_0's auc: 0.945698
# [1]	valid_0's auc: 0.926282
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.92737
# [3]	valid_0's auc: 0.928177
# [4]	valid_0's auc: 0.928894
# [5]	valid_0's auc: 0.92913
# [6]	valid_0's auc: 0.929196
# [7]	valid_0's auc: 0.929349
# [8]	valid_0's auc: 0.929639
# [9]	valid_0's auc: 0.929769
# [10]	valid_0's auc: 0.929825
# [11]	valid_0's auc: 0.93418
# [12]	valid_0's auc: 0.938183
# [13]	valid_0's auc: 0.938975
# [14]	valid_0's auc: 0.938933
# [15]	valid_0's auc: 0.938884
# [16]	valid_0's auc: 0.939064
# [17]	valid_0's auc: 0.93965
# [18]	valid_0's auc: 0.939736
# [19]	valid_0's auc: 0.940088
# [20]	valid_0's auc: 0.940231
# [21]	valid_0's auc: 0.940361
# [22]	valid_0's auc: 0.940556
# [23]	valid_0's auc: 0.940802
# [24]	valid_0's auc: 0.941016
# [25]	valid_0's auc: 0.941057
# [26]	valid_0's auc: 0.941143
# [27]	valid_0's auc: 0.941187
# [28]	valid_0's auc: 0.9415
# [29]	valid_0's auc: 0.942364
# [30]	valid_0's auc: 0.94298
# [31]	valid_0's auc: 0.943225
# [32]	valid_0's auc: 0.943515
# [33]	valid_0's auc: 0.943717
# [34]	valid_0's auc: 0.943856
# [35]	valid_0's auc: 0.943886
# [36]	valid_0's auc: 0.94403
# [37]	valid_0's auc: 0.943982
# [38]	valid_0's auc: 0.943972
# [39]	valid_0's auc: 0.944094
# [40]	valid_0's auc: 0.944215
# [41]	valid_0's auc: 0.944397
# [42]	valid_0's auc: 0.944344
# [43]	valid_0's auc: 0.944349
# [44]	valid_0's auc: 0.944365
# [45]	valid_0's auc: 0.944432
# [46]	valid_0's auc: 0.944514
# [47]	valid_0's auc: 0.944756
# [48]	valid_0's auc: 0.944866
# [49]	valid_0's auc: 0.944927
# [50]	valid_0's auc: 0.94495
# [51]	valid_0's auc: 0.945137
# [52]	valid_0's auc: 0.945282
# [53]	valid_0's auc: 0.945314
# [54]	valid_0's auc: 0.945291
# [55]	valid_0's auc: 0.945273
# [56]	valid_0's auc: 0.945335
# [57]	valid_0's auc: 0.945375
# [58]	valid_0's auc: 0.945444
# [59]	valid_0's auc: 0.945418
# [60]	valid_0's auc: 0.945427
# [61]	valid_0's auc: 0.945469
# [62]	valid_0's auc: 0.945453
# [63]	valid_0's auc: 0.945495
# [64]	valid_0's auc: 0.945556
# [65]	valid_0's auc: 0.945495
# [66]	valid_0's auc: 0.945511
# [67]	valid_0's auc: 0.945543
# [68]	valid_0's auc: 0.945584
# [69]	valid_0's auc: 0.945626
# [70]	valid_0's auc: 0.945596
# [71]	valid_0's auc: 0.945679
# [72]	valid_0's auc: 0.945697
# [73]	valid_0's auc: 0.945686
# [74]	valid_0's auc: 0.945659
# [75]	valid_0's auc: 0.945624
# [76]	valid_0's auc: 0.945713
# [77]	valid_0's auc: 0.945743
# [78]	valid_0's auc: 0.945676
# [79]	valid_0's auc: 0.945681
# [80]	valid_0's auc: 0.945687
# [81]	valid_0's auc: 0.945691
# [82]	valid_0's auc: 0.945657
# [83]	valid_0's auc: 0.945657
# [84]	valid_0's auc: 0.94564
# [85]	valid_0's auc: 0.945625
# [86]	valid_0's auc: 0.945584
# [87]	valid_0's auc: 0.945626
# [88]	valid_0's auc: 0.945608
# [89]	valid_0's auc: 0.945583
# [90]	valid_0's auc: 0.94564
# [91]	valid_0's auc: 0.94566
# [92]	valid_0's auc: 0.945645
# [93]	valid_0's auc: 0.945613
# [94]	valid_0's auc: 0.945608
# [95]	valid_0's auc: 0.945606
# [96]	valid_0's auc: 0.945577
# [97]	valid_0's auc: 0.945565
# [98]	valid_0's auc: 0.945542
# [99]	valid_0's auc: 0.945531
# [100]	valid_0's auc: 0.94554
# [101]	valid_0's auc: 0.945546
# [102]	valid_0's auc: 0.945519
# Early stopping, best iteration is:
# [77]	valid_0's auc: 0.945743
# Unprinv: age 0.0
# [1]	valid_0's auc: 0.924914
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.926797
# [3]	valid_0's auc: 0.927822
# [4]	valid_0's auc: 0.92886
# [5]	valid_0's auc: 0.931675
# [6]	valid_0's auc: 0.931906
# [7]	valid_0's auc: 0.932374
# [8]	valid_0's auc: 0.932472
# [9]	valid_0's auc: 0.934975
# [10]	valid_0's auc: 0.935233
# [11]	valid_0's auc: 0.93681
# [12]	valid_0's auc: 0.937075
# [13]	valid_0's auc: 0.93704
# [14]	valid_0's auc: 0.937183
# [15]	valid_0's auc: 0.937248
# [16]	valid_0's auc: 0.93952
# [17]	valid_0's auc: 0.939748
# [18]	valid_0's auc: 0.94003
# [19]	valid_0's auc: 0.9405
# [20]	valid_0's auc: 0.940934
# [21]	valid_0's auc: 0.941854
# [22]	valid_0's auc: 0.941948
# [23]	valid_0's auc: 0.942005
# [24]	valid_0's auc: 0.942171
# [25]	valid_0's auc: 0.942051
# [26]	valid_0's auc: 0.942146
# [27]	valid_0's auc: 0.942382
# [28]	valid_0's auc: 0.942805
# [29]	valid_0's auc: 0.942997
# [30]	valid_0's auc: 0.943174
# [31]	valid_0's auc: 0.943321
# [32]	valid_0's auc: 0.943265
# [33]	valid_0's auc: 0.943307
# [34]	valid_0's auc: 0.943608
# [35]	valid_0's auc: 0.943758
# [36]	valid_0's auc: 0.94389
# [37]	valid_0's auc: 0.944073
# [38]	valid_0's auc: 0.944294
# [39]	valid_0's auc: 0.944327
# [40]	valid_0's auc: 0.944317
# [41]	valid_0's auc: 0.94492
# [42]	valid_0's auc: 0.945373
# [43]	valid_0's auc: 0.945529
# [44]	valid_0's auc: 0.945678
# [45]	valid_0's auc: 0.945833
# [46]	valid_0's auc: 0.946023
# [47]	valid_0's auc: 0.946116
# [48]	valid_0's auc: 0.946181
# [49]	valid_0's auc: 0.946251
# [50]	valid_0's auc: 0.946321
# [51]	valid_0's auc: 0.946418
# [52]	valid_0's auc: 0.946513
# [53]	valid_0's auc: 0.946567
# [54]	valid_0's auc: 0.946565
# [55]	valid_0's auc: 0.946581
# [56]	valid_0's auc: 0.946616
# [57]	valid_0's auc: 0.946623
# [58]	valid_0's auc: 0.946683
# [59]	valid_0's auc: 0.946633
# [60]	valid_0's auc: 0.946822
# [61]	valid_0's auc: 0.946834
# [62]	valid_0's auc: 0.946748
# [63]	valid_0's auc: 0.946786
# [64]	valid_0's auc: 0.946972
# [65]	valid_0's auc: 0.947006
# [66]	valid_0's auc: 0.947088
# [67]	valid_0's auc: 0.947108
# [68]	valid_0's auc: 0.947162
# [69]	valid_0's auc: 0.947194
# [70]	valid_0's auc: 0.947223
# [71]	valid_0's auc: 0.947227
# [72]	valid_0's auc: 0.947249
# [73]	valid_0's auc: 0.947331
# [74]	valid_0's auc: 0.947342
# [75]	valid_0's auc: 0.947336
# [76]	valid_0's auc: 0.947304
# [77]	valid_0's auc: 0.947307
# [78]	valid_0's auc: 0.947284
# [79]	valid_0's auc: 0.947278
# [80]	valid_0's auc: 0.947269
# [81]	valid_0's auc: 0.947238
# [82]	valid_0's auc: 0.947246
# [83]	valid_0's auc: 0.947275
# [84]	valid_0's auc: 0.94729
# [85]	valid_0's auc: 0.947333
# [86]	valid_0's auc: 0.947326
# [87]	valid_0's auc: 0.947318
# [88]	valid_0's auc: 0.947339
# [89]	valid_0's auc: 0.947332
# [90]	valid_0's auc: 0.947346
# [91]	valid_0's auc: 0.947339
# [92]	valid_0's auc: 0.947329
# [93]	valid_0's auc: 0.94729
# [94]	valid_0's auc: 0.947258
# [95]	valid_0's auc: 0.947268
# [96]	valid_0's auc: 0.947239
# [97]	valid_0's auc: 0.947243
# [98]	valid_0's auc: 0.947224
# [99]	valid_0's auc: 0.947229
# [100]	valid_0's auc: 0.947191
# [101]	valid_0's auc: 0.947242
# [102]	valid_0's auc: 0.947236
# [103]	valid_0's auc: 0.947204
# [104]	valid_0's auc: 0.947208
# [105]	valid_0's auc: 0.947226
# [106]	valid_0's auc: 0.947182
# [107]	valid_0's auc: 0.947141
# [108]	valid_0's auc: 0.947179
# [109]	valid_0's auc: 0.947153
# [110]	valid_0's auc: 0.947114
# [111]	valid_0's auc: 0.947124
# [112]	valid_0's auc: 0.947117
# [113]	valid_0's auc: 0.947099
# [114]	valid_0's auc: 0.947101
# [115]	valid_0's auc: 0.947125
# Early stopping, best iteration is:
# [90]	valid_0's auc: 0.947346
# [1]	valid_0's auc: 0.923283
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.925218
# [3]	valid_0's auc: 0.926935
# [4]	valid_0's auc: 0.927344
# [5]	valid_0's auc: 0.931212
# [6]	valid_0's auc: 0.931541
# [7]	valid_0's auc: 0.93191
# [8]	valid_0's auc: 0.932065
# [9]	valid_0's auc: 0.934518
# [10]	valid_0's auc: 0.934691
# [11]	valid_0's auc: 0.93589
# [12]	valid_0's auc: 0.936324
# [13]	valid_0's auc: 0.936498
# [14]	valid_0's auc: 0.936587
# [15]	valid_0's auc: 0.936757
# [16]	valid_0's auc: 0.939402
# [17]	valid_0's auc: 0.939665
# [18]	valid_0's auc: 0.939867
# [19]	valid_0's auc: 0.940405
# [20]	valid_0's auc: 0.940668
# [21]	valid_0's auc: 0.9407
# [22]	valid_0's auc: 0.941813
# [23]	valid_0's auc: 0.941993
# [24]	valid_0's auc: 0.94199
# [25]	valid_0's auc: 0.94239
# [26]	valid_0's auc: 0.942525
# [27]	valid_0's auc: 0.942804
# [28]	valid_0's auc: 0.942906
# [29]	valid_0's auc: 0.943018
# [30]	valid_0's auc: 0.94311
# [31]	valid_0's auc: 0.943135
# [32]	valid_0's auc: 0.94316
# [33]	valid_0's auc: 0.943223
# [34]	valid_0's auc: 0.943491
# [35]	valid_0's auc: 0.943524
# [36]	valid_0's auc: 0.943562
# [37]	valid_0's auc: 0.943614
# [38]	valid_0's auc: 0.944258
# [39]	valid_0's auc: 0.944562
# [40]	valid_0's auc: 0.944698
# [41]	valid_0's auc: 0.944779
# [42]	valid_0's auc: 0.945201
# [43]	valid_0's auc: 0.945249
# [44]	valid_0's auc: 0.945442
# [45]	valid_0's auc: 0.94575
# [46]	valid_0's auc: 0.945916
# [47]	valid_0's auc: 0.946192
# [48]	valid_0's auc: 0.946269
# [49]	valid_0's auc: 0.946336
# [50]	valid_0's auc: 0.946357
# [51]	valid_0's auc: 0.946364
# [52]	valid_0's auc: 0.946424
# [53]	valid_0's auc: 0.946434
# [54]	valid_0's auc: 0.946497
# [55]	valid_0's auc: 0.94651
# [56]	valid_0's auc: 0.94652
# [57]	valid_0's auc: 0.946518
# [58]	valid_0's auc: 0.946564
# [59]	valid_0's auc: 0.946654
# [60]	valid_0's auc: 0.946695
# [61]	valid_0's auc: 0.946798
# [62]	valid_0's auc: 0.946846
# [63]	valid_0's auc: 0.946855
# [64]	valid_0's auc: 0.946945
# [65]	valid_0's auc: 0.946972
# [66]	valid_0's auc: 0.947015
# [67]	valid_0's auc: 0.947094
# [68]	valid_0's auc: 0.947109
# [69]	valid_0's auc: 0.947122
# [70]	valid_0's auc: 0.947164
# [71]	valid_0's auc: 0.94721
# [72]	valid_0's auc: 0.947263
# [73]	valid_0's auc: 0.947286
# [74]	valid_0's auc: 0.947274
# [75]	valid_0's auc: 0.947257
# [76]	valid_0's auc: 0.947216
# [77]	valid_0's auc: 0.947235
# [78]	valid_0's auc: 0.947268
# [79]	valid_0's auc: 0.947298
# [80]	valid_0's auc: 0.94724
# [81]	valid_0's auc: 0.947251
# [82]	valid_0's auc: 0.947303
# [83]	valid_0's auc: 0.947308
# [84]	valid_0's auc: 0.947282
# [85]	valid_0's auc: 0.94727
# [86]	valid_0's auc: 0.947279
# [87]	valid_0's auc: 0.947296
# [88]	valid_0's auc: 0.947293
# [89]	valid_0's auc: 0.947297
# [90]	valid_0's auc: 0.947309
# [91]	valid_0's auc: 0.947304
# [92]	valid_0's auc: 0.947321
# [93]	valid_0's auc: 0.947354
# [94]	valid_0's auc: 0.947378
# [95]	valid_0's auc: 0.94739
# [96]	valid_0's auc: 0.947387
# [97]	valid_0's auc: 0.947405
# [98]	valid_0's auc: 0.947411
# [99]	valid_0's auc: 0.947439
# [100]	valid_0's auc: 0.947419
# [101]	valid_0's auc: 0.947426
# [102]	valid_0's auc: 0.947456
# [103]	valid_0's auc: 0.947429
# [104]	valid_0's auc: 0.947437
# [105]	valid_0's auc: 0.947433
# [106]	valid_0's auc: 0.947445
# [107]	valid_0's auc: 0.947466
# [108]	valid_0's auc: 0.947491
# [109]	valid_0's auc: 0.94745
# [110]	valid_0's auc: 0.947479
# [111]	valid_0's auc: 0.947461
# [112]	valid_0's auc: 0.947467
# [113]	valid_0's auc: 0.94746
# [114]	valid_0's auc: 0.947466
# [115]	valid_0's auc: 0.947484
# [116]	valid_0's auc: 0.947498
# [117]	valid_0's auc: 0.947477
# [118]	valid_0's auc: 0.94745
# [119]	valid_0's auc: 0.947442
# [120]	valid_0's auc: 0.947446
# [121]	valid_0's auc: 0.94741
# [122]	valid_0's auc: 0.947336
# [123]	valid_0's auc: 0.947316
# [124]	valid_0's auc: 0.947316
# [125]	valid_0's auc: 0.947299
# [126]	valid_0's auc: 0.94729
# [127]	valid_0's auc: 0.947246
# [128]	valid_0's auc: 0.947263
# [129]	valid_0's auc: 0.947245
# [130]	valid_0's auc: 0.947258
# [131]	valid_0's auc: 0.947226
# [132]	valid_0's auc: 0.947193
# [133]	valid_0's auc: 0.947182
# [134]	valid_0's auc: 0.947153
# [135]	valid_0's auc: 0.947189
# [136]	valid_0's auc: 0.947198
# [137]	valid_0's auc: 0.947196
# [138]	valid_0's auc: 0.947219
# [139]	valid_0's auc: 0.947257
# [140]	valid_0's auc: 0.947228
# [141]	valid_0's auc: 0.947204
# Early stopping, best iteration is:
# [116]	valid_0's auc: 0.947498
# Unprinv: age 0.0
# [1]	valid_0's auc: 0.915733
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.917479
# [3]	valid_0's auc: 0.921544
# [4]	valid_0's auc: 0.922538
# [5]	valid_0's auc: 0.92462
# [6]	valid_0's auc: 0.926687
# [7]	valid_0's auc: 0.926666
# [8]	valid_0's auc: 0.926781
# [9]	valid_0's auc: 0.932093
# [10]	valid_0's auc: 0.932367
# [11]	valid_0's auc: 0.934091
# [12]	valid_0's auc: 0.934302
# [13]	valid_0's auc: 0.936423
# [14]	valid_0's auc: 0.936681
# [15]	valid_0's auc: 0.936782
# [16]	valid_0's auc: 0.93694
# [17]	valid_0's auc: 0.937104
# [18]	valid_0's auc: 0.937187
# [19]	valid_0's auc: 0.937356
# [20]	valid_0's auc: 0.937264
# [21]	valid_0's auc: 0.937401
# [22]	valid_0's auc: 0.937489
# [23]	valid_0's auc: 0.937648
# [24]	valid_0's auc: 0.937708
# [25]	valid_0's auc: 0.937837
# [26]	valid_0's auc: 0.93831
# [27]	valid_0's auc: 0.938583
# [28]	valid_0's auc: 0.938788
# [29]	valid_0's auc: 0.939327
# [30]	valid_0's auc: 0.939755
# [31]	valid_0's auc: 0.939999
# [32]	valid_0's auc: 0.940114
# [33]	valid_0's auc: 0.940437
# [34]	valid_0's auc: 0.940543
# [35]	valid_0's auc: 0.940787
# [36]	valid_0's auc: 0.940868
# [37]	valid_0's auc: 0.941118
# [38]	valid_0's auc: 0.941288
# [39]	valid_0's auc: 0.941337
# [40]	valid_0's auc: 0.941502
# [41]	valid_0's auc: 0.941928
# [42]	valid_0's auc: 0.942086
# [43]	valid_0's auc: 0.942092
# [44]	valid_0's auc: 0.942228
# [45]	valid_0's auc: 0.942274
# [46]	valid_0's auc: 0.94238
# [47]	valid_0's auc: 0.942459
# [48]	valid_0's auc: 0.942496
# [49]	valid_0's auc: 0.942564
# [50]	valid_0's auc: 0.942608
# [51]	valid_0's auc: 0.942738
# [52]	valid_0's auc: 0.942747
# [53]	valid_0's auc: 0.94278
# [54]	valid_0's auc: 0.942836
# [55]	valid_0's auc: 0.94294
# [56]	valid_0's auc: 0.942955
# [57]	valid_0's auc: 0.942937
# [58]	valid_0's auc: 0.942995
# [59]	valid_0's auc: 0.942971
# [60]	valid_0's auc: 0.943059
# [61]	valid_0's auc: 0.943151
# [62]	valid_0's auc: 0.943201
# [63]	valid_0's auc: 0.943265
# [64]	valid_0's auc: 0.943246
# [65]	valid_0's auc: 0.94327
# [66]	valid_0's auc: 0.943333
# [67]	valid_0's auc: 0.943378
# [68]	valid_0's auc: 0.943349
# [69]	valid_0's auc: 0.943354
# [70]	valid_0's auc: 0.943378
# [71]	valid_0's auc: 0.943462
# [72]	valid_0's auc: 0.943435
# [73]	valid_0's auc: 0.943487
# [74]	valid_0's auc: 0.943436
# [75]	valid_0's auc: 0.943477
# [76]	valid_0's auc: 0.943467
# [77]	valid_0's auc: 0.943494
# [78]	valid_0's auc: 0.94346
# [79]	valid_0's auc: 0.943466
# [80]	valid_0's auc: 0.943439
# [81]	valid_0's auc: 0.943434
# [82]	valid_0's auc: 0.943516
# [83]	valid_0's auc: 0.943541
# [84]	valid_0's auc: 0.943506
# [85]	valid_0's auc: 0.943478
# [86]	valid_0's auc: 0.943486
# [87]	valid_0's auc: 0.943468
# [88]	valid_0's auc: 0.943461
# [89]	valid_0's auc: 0.943471
# [90]	valid_0's auc: 0.943509
# [91]	valid_0's auc: 0.943484
# [92]	valid_0's auc: 0.943533
# [93]	valid_0's auc: 0.94353
# [94]	valid_0's auc: 0.943507
# [95]	valid_0's auc: 0.943502
# [96]	valid_0's auc: 0.943531
# [97]	valid_0's auc: 0.943564
# [98]	valid_0's auc: 0.943557
# [99]	valid_0's auc: 0.943569
# [100]	valid_0's auc: 0.943551
# [101]	valid_0's auc: 0.943548
# [102]	valid_0's auc: 0.943574
# [103]	valid_0's auc: 0.943524
# [104]	valid_0's auc: 0.94353
# [105]	valid_0's auc: 0.943508
# [106]	valid_0's auc: 0.943563
# [107]	valid_0's auc: 0.94359
# [108]	valid_0's auc: 0.943587
# [109]	valid_0's auc: 0.943638
# [110]	valid_0's auc: 0.943606
# [111]	valid_0's auc: 0.94359
# [112]	valid_0's auc: 0.943592
# [113]	valid_0's auc: 0.943615
# [114]	valid_0's auc: 0.943559
# [115]	valid_0's auc: 0.943576
# [116]	valid_0's auc: 0.943538
# [117]	valid_0's auc: 0.943508
# [118]	valid_0's auc: 0.943512
# [119]	valid_0's auc: 0.943542
# [120]	valid_0's auc: 0.943509
# [121]	valid_0's auc: 0.943491
# [122]	valid_0's auc: 0.943456
# [123]	valid_0's auc: 0.943485
# [124]	valid_0's auc: 0.943481
# [125]	valid_0's auc: 0.943477
# [126]	valid_0's auc: 0.94344
# [127]	valid_0's auc: 0.943435
# [128]	valid_0's auc: 0.943424
# [129]	valid_0's auc: 0.943416
# [130]	valid_0's auc: 0.943414
# [131]	valid_0's auc: 0.94343
# [132]	valid_0's auc: 0.943436
# [133]	valid_0's auc: 0.943446
# [134]	valid_0's auc: 0.943478
# Early stopping, best iteration is:
# [109]	valid_0's auc: 0.943638
# [1]	valid_0's auc: 0.914997
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.917271
# [3]	valid_0's auc: 0.921554
# [4]	valid_0's auc: 0.922084
# [5]	valid_0's auc: 0.924551
# [6]	valid_0's auc: 0.926577
# [7]	valid_0's auc: 0.926837
# [8]	valid_0's auc: 0.92686
# [9]	valid_0's auc: 0.927078
# [10]	valid_0's auc: 0.932286
# [11]	valid_0's auc: 0.934434
# [12]	valid_0's auc: 0.934796
# [13]	valid_0's auc: 0.937587
# [14]	valid_0's auc: 0.937594
# [15]	valid_0's auc: 0.937708
# [16]	valid_0's auc: 0.937655
# [17]	valid_0's auc: 0.937595
# [18]	valid_0's auc: 0.937729
# [19]	valid_0's auc: 0.93781
# [20]	valid_0's auc: 0.938317
# [21]	valid_0's auc: 0.938583
# [22]	valid_0's auc: 0.938844
# [23]	valid_0's auc: 0.938939
# [24]	valid_0's auc: 0.938899
# [25]	valid_0's auc: 0.938932
# [26]	valid_0's auc: 0.939063
# [27]	valid_0's auc: 0.939103
# [28]	valid_0's auc: 0.939184
# [29]	valid_0's auc: 0.939266
# [30]	valid_0's auc: 0.939345
# [31]	valid_0's auc: 0.939737
# [32]	valid_0's auc: 0.940149
# [33]	valid_0's auc: 0.940247
# [34]	valid_0's auc: 0.940392
# [35]	valid_0's auc: 0.940553
# [36]	valid_0's auc: 0.940651
# [37]	valid_0's auc: 0.940751
# [38]	valid_0's auc: 0.940865
# [39]	valid_0's auc: 0.940974
# [40]	valid_0's auc: 0.941488
# [41]	valid_0's auc: 0.941612
# [42]	valid_0's auc: 0.941728
# [43]	valid_0's auc: 0.941774
# [44]	valid_0's auc: 0.941881
# [45]	valid_0's auc: 0.941931
# [46]	valid_0's auc: 0.942061
# [47]	valid_0's auc: 0.942145
# [48]	valid_0's auc: 0.94221
# [49]	valid_0's auc: 0.942272
# [50]	valid_0's auc: 0.942415
# [51]	valid_0's auc: 0.942448
# [52]	valid_0's auc: 0.942544
# [53]	valid_0's auc: 0.942577
# [54]	valid_0's auc: 0.942646
# [55]	valid_0's auc: 0.942719
# [56]	valid_0's auc: 0.942819
# [57]	valid_0's auc: 0.94285
# [58]	valid_0's auc: 0.942858
# [59]	valid_0's auc: 0.942967
# [60]	valid_0's auc: 0.943087
# [61]	valid_0's auc: 0.943135
# [62]	valid_0's auc: 0.943129
# [63]	valid_0's auc: 0.943193
# [64]	valid_0's auc: 0.943151
# [65]	valid_0's auc: 0.943239
# [66]	valid_0's auc: 0.943269
# [67]	valid_0's auc: 0.94327
# [68]	valid_0's auc: 0.943312
# [69]	valid_0's auc: 0.943315
# [70]	valid_0's auc: 0.943273
# [71]	valid_0's auc: 0.943243
# [72]	valid_0's auc: 0.943245
# [73]	valid_0's auc: 0.943255
# [74]	valid_0's auc: 0.943298
# [75]	valid_0's auc: 0.943293
# [76]	valid_0's auc: 0.943314
# [77]	valid_0's auc: 0.943301
# [78]	valid_0's auc: 0.943321
# [79]	valid_0's auc: 0.94328
# [80]	valid_0's auc: 0.943291
# [81]	valid_0's auc: 0.943257
# [82]	valid_0's auc: 0.943288
# [83]	valid_0's auc: 0.943246
# [84]	valid_0's auc: 0.943263
# [85]	valid_0's auc: 0.94327
# [86]	valid_0's auc: 0.94327
# [87]	valid_0's auc: 0.943264
# [88]	valid_0's auc: 0.943253
# [89]	valid_0's auc: 0.94324
# [90]	valid_0's auc: 0.943206
# [91]	valid_0's auc: 0.94315
# [92]	valid_0's auc: 0.943137
# [93]	valid_0's auc: 0.943157
# [94]	valid_0's auc: 0.943198
# [95]	valid_0's auc: 0.943237
# [96]	valid_0's auc: 0.943241
# [97]	valid_0's auc: 0.943296
# [98]	valid_0's auc: 0.943296
# [99]	valid_0's auc: 0.943309
# [100]	valid_0's auc: 0.943313
# [101]	valid_0's auc: 0.943337
# [102]	valid_0's auc: 0.943363
# [103]	valid_0's auc: 0.943313
# [104]	valid_0's auc: 0.943301
# [105]	valid_0's auc: 0.943286
# [106]	valid_0's auc: 0.943242
# [107]	valid_0's auc: 0.943293
# [108]	valid_0's auc: 0.943226
# [109]	valid_0's auc: 0.943195
# [110]	valid_0's auc: 0.943192
# [111]	valid_0's auc: 0.943238
# [112]	valid_0's auc: 0.943248
# [113]	valid_0's auc: 0.943288
# [114]	valid_0's auc: 0.943298
# [115]	valid_0's auc: 0.943312
# [116]	valid_0's auc: 0.943329
# [117]	valid_0's auc: 0.943318
# [118]	valid_0's auc: 0.943317
# [119]	valid_0's auc: 0.943312
# [120]	valid_0's auc: 0.943277
# [121]	valid_0's auc: 0.943279
# [122]	valid_0's auc: 0.943236
# [123]	valid_0's auc: 0.943249
# [124]	valid_0's auc: 0.943194
# [125]	valid_0's auc: 0.943227
# [126]	valid_0's auc: 0.943211
# [127]	valid_0's auc: 0.943224
# Early stopping, best iteration is:
# [102]	valid_0's auc: 0.943363
# Unprinv: age 0.0
# [1]	valid_0's auc: 0.922197
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.926101
# [3]	valid_0's auc: 0.926012
# [4]	valid_0's auc: 0.927011
# [5]	valid_0's auc: 0.927245
# [6]	valid_0's auc: 0.927636
# [7]	valid_0's auc: 0.927697
# [8]	valid_0's auc: 0.932156
# [9]	valid_0's auc: 0.932411
# [10]	valid_0's auc: 0.933308
# [11]	valid_0's auc: 0.934532
# [12]	valid_0's auc: 0.934765
# [13]	valid_0's auc: 0.93642
# [14]	valid_0's auc: 0.936464
# [15]	valid_0's auc: 0.93661
# [16]	valid_0's auc: 0.937432
# [17]	valid_0's auc: 0.93759
# [18]	valid_0's auc: 0.937668
# [19]	valid_0's auc: 0.937954
# [20]	valid_0's auc: 0.938249
# [21]	valid_0's auc: 0.938517
# [22]	valid_0's auc: 0.938671
# [23]	valid_0's auc: 0.938746
# [24]	valid_0's auc: 0.939231
# [25]	valid_0's auc: 0.939151
# [26]	valid_0's auc: 0.939382
# [27]	valid_0's auc: 0.939452
# [28]	valid_0's auc: 0.939484
# [29]	valid_0's auc: 0.939513
# [30]	valid_0's auc: 0.939556
# [31]	valid_0's auc: 0.939853
# [32]	valid_0's auc: 0.940006
# [33]	valid_0's auc: 0.940095
# [34]	valid_0's auc: 0.940269
# [35]	valid_0's auc: 0.940304
# [36]	valid_0's auc: 0.940935
# [37]	valid_0's auc: 0.941123
# [38]	valid_0's auc: 0.940977
# [39]	valid_0's auc: 0.941234
# [40]	valid_0's auc: 0.941545
# [41]	valid_0's auc: 0.941521
# [42]	valid_0's auc: 0.941974
# [43]	valid_0's auc: 0.942183
# [44]	valid_0's auc: 0.94222
# [45]	valid_0's auc: 0.942275
# [46]	valid_0's auc: 0.942485
# [47]	valid_0's auc: 0.942717
# [48]	valid_0's auc: 0.942663
# [49]	valid_0's auc: 0.942789
# [50]	valid_0's auc: 0.942881
# [51]	valid_0's auc: 0.94283
# [52]	valid_0's auc: 0.94295
# [53]	valid_0's auc: 0.943019
# [54]	valid_0's auc: 0.943043
# [55]	valid_0's auc: 0.943043
# [56]	valid_0's auc: 0.943137
# [57]	valid_0's auc: 0.943161
# [58]	valid_0's auc: 0.943235
# [59]	valid_0's auc: 0.943314
# [60]	valid_0's auc: 0.943298
# [61]	valid_0's auc: 0.943316
# [62]	valid_0's auc: 0.943282
# [63]	valid_0's auc: 0.943287
# [64]	valid_0's auc: 0.943311
# [65]	valid_0's auc: 0.943301
# [66]	valid_0's auc: 0.94334
# [67]	valid_0's auc: 0.943408
# [68]	valid_0's auc: 0.943419
# [69]	valid_0's auc: 0.943447
# [70]	valid_0's auc: 0.943419
# [71]	valid_0's auc: 0.943431
# [72]	valid_0's auc: 0.943476
# [73]	valid_0's auc: 0.943493
# [74]	valid_0's auc: 0.943473
# [75]	valid_0's auc: 0.943486
# [76]	valid_0's auc: 0.94347
# [77]	valid_0's auc: 0.943464
# [78]	valid_0's auc: 0.943431
# [79]	valid_0's auc: 0.94345
# [80]	valid_0's auc: 0.943409
# [81]	valid_0's auc: 0.943393
# [82]	valid_0's auc: 0.943381
# [83]	valid_0's auc: 0.943418
# [84]	valid_0's auc: 0.94343
# [85]	valid_0's auc: 0.943435
# [86]	valid_0's auc: 0.943404
# [87]	valid_0's auc: 0.94339
# [88]	valid_0's auc: 0.943417
# [89]	valid_0's auc: 0.943399
# [90]	valid_0's auc: 0.943391
# [91]	valid_0's auc: 0.943428
# [92]	valid_0's auc: 0.943446
# [93]	valid_0's auc: 0.943446
# [94]	valid_0's auc: 0.943414
# [95]	valid_0's auc: 0.943443
# [96]	valid_0's auc: 0.943485
# [97]	valid_0's auc: 0.94347
# [98]	valid_0's auc: 0.943452
# Early stopping, best iteration is:
# [73]	valid_0's auc: 0.943493
# [1]	valid_0's auc: 0.92016
# Training until validation scores don't improve for 25 rounds
# [2]	valid_0's auc: 0.923561
# [3]	valid_0's auc: 0.925329
# [4]	valid_0's auc: 0.926036
# [5]	valid_0's auc: 0.926141
# [6]	valid_0's auc: 0.926163
# [7]	valid_0's auc: 0.926732
# [8]	valid_0's auc: 0.931293
# [9]	valid_0's auc: 0.932315
# [10]	valid_0's auc: 0.933027
# [11]	valid_0's auc: 0.934144
# [12]	valid_0's auc: 0.935939
# [13]	valid_0's auc: 0.93606
# [14]	valid_0's auc: 0.936071
# [15]	valid_0's auc: 0.936123
# [16]	valid_0's auc: 0.937094
# [17]	valid_0's auc: 0.937262
# [18]	valid_0's auc: 0.937148
# [19]	valid_0's auc: 0.937118
# [20]	valid_0's auc: 0.937579
# [21]	valid_0's auc: 0.93776
# [22]	valid_0's auc: 0.93804
# [23]	valid_0's auc: 0.938153
# [24]	valid_0's auc: 0.938574
# [25]	valid_0's auc: 0.938677
# [26]	valid_0's auc: 0.938611
# [27]	valid_0's auc: 0.938609
# [28]	valid_0's auc: 0.938748
# [29]	valid_0's auc: 0.93876
# [30]	valid_0's auc: 0.939285
# [31]	valid_0's auc: 0.939427
# [32]	valid_0's auc: 0.939491
# [33]	valid_0's auc: 0.939643
# [34]	valid_0's auc: 0.939767
# [35]	valid_0's auc: 0.939819
# [36]	valid_0's auc: 0.940458
# [37]	valid_0's auc: 0.940584
# [38]	valid_0's auc: 0.940623
# [39]	valid_0's auc: 0.941051
# [40]	valid_0's auc: 0.941172
# [41]	valid_0's auc: 0.941277
# [42]	valid_0's auc: 0.941613
# [43]	valid_0's auc: 0.941857
# [44]	valid_0's auc: 0.941963
# [45]	valid_0's auc: 0.94239
# [46]	valid_0's auc: 0.942505
# [47]	valid_0's auc: 0.942626
# [48]	valid_0's auc: 0.942687
# [49]	valid_0's auc: 0.942765
# [50]	valid_0's auc: 0.94277
# [51]	valid_0's auc: 0.94289
# [52]	valid_0's auc: 0.942831
# [53]	valid_0's auc: 0.942866
# [54]	valid_0's auc: 0.942881
# [55]	valid_0's auc: 0.942975
# [56]	valid_0's auc: 0.942994
# [57]	valid_0's auc: 0.942998
# [58]	valid_0's auc: 0.942993
# [59]	valid_0's auc: 0.943064
# [60]	valid_0's auc: 0.943078
# [61]	valid_0's auc: 0.943193
# [62]	valid_0's auc: 0.943216
# [63]	valid_0's auc: 0.943261
# [64]	valid_0's auc: 0.943267
# [65]	valid_0's auc: 0.943291
# [66]	valid_0's auc: 0.943336
# [67]	valid_0's auc: 0.943369
# [68]	valid_0's auc: 0.94339
# [69]	valid_0's auc: 0.943375
# [70]	valid_0's auc: 0.943487
# [71]	valid_0's auc: 0.943546
# [72]	valid_0's auc: 0.943585
# [73]	valid_0's auc: 0.943555
# [74]	valid_0's auc: 0.943634
# [75]	valid_0's auc: 0.943652
# [76]	valid_0's auc: 0.94366
# [77]	valid_0's auc: 0.943629
# [78]	valid_0's auc: 0.943616
# [79]	valid_0's auc: 0.943619
# [80]	valid_0's auc: 0.943613
# [81]	valid_0's auc: 0.943639
# [82]	valid_0's auc: 0.943688
# [83]	valid_0's auc: 0.943649
# [84]	valid_0's auc: 0.943608
# [85]	valid_0's auc: 0.943616
# [86]	valid_0's auc: 0.943647
# [87]	valid_0's auc: 0.943646
# [88]	valid_0's auc: 0.94364
# [89]	valid_0's auc: 0.943661
# [90]	valid_0's auc: 0.943642
# [91]	valid_0's auc: 0.943659
# [92]	valid_0's auc: 0.943656
# [93]	valid_0's auc: 0.943656
# [94]	valid_0's auc: 0.943627
# [95]	valid_0's auc: 0.943643
# [96]	valid_0's auc: 0.943627
# [97]	valid_0's auc: 0.943652
# [98]	valid_0's auc: 0.943635
# [99]	valid_0's auc: 0.943621
# [100]	valid_0's auc: 0.943623
# [101]	valid_0's auc: 0.94361
# [102]	valid_0's auc: 0.943642
# [103]	valid_0's auc: 0.943609
# [104]	valid_0's auc: 0.943629
# [105]	valid_0's auc: 0.943633
# [106]	valid_0's auc: 0.943594
# [107]	valid_0's auc: 0.943596
# Early stopping, best iteration is:
# [82]	valid_0's auc: 0.943688
# Unprinv: age 0.0
